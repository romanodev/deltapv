# %%
import jaxpv
import jax.numpy as np
from jax import grad, jacfwd, jit
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
N = 500
material = jaxpv.Material()["Si"]
material["A"] = 1e4
grid = np.linspace(0, 3e-4, N)
sim = jaxpv.JAXPV(grid)
sim.add_material(material, np.arange(N))
sim.contacts(1e7, 0, 0, 1e7)
sim.single_pn_junction(1e17, -1e15, 50e-7)
# phi = 1e17
# alpha = 2.3e4
# G = phi * alpha * np.exp(-alpha * grid)
# sim.optical_G("user", G)
sim.incident_light(kind="sun")
sim.optical_G(kind="direct")
gradeff = grad(jaxpv.efficiency)

# %%
eff = jaxpv.efficiency(sim.data, sim.opt)
gradients = gradeff(sim.data, sim.opt)
# Out:
# Solving equilibrium...
# 	 iteration: 1          error: 41.13642567240284
# 	 iteration: 2          error: 33.504281267105455
# 	 iteration: 3          error: 23.29819047250992
# 	 iteration: 4          error: 14.150280436177582
# 	 iteration: 5          error: 7.056006519891492
# 	 iteration: 6          error: 2.799726615491106
# 	 iteration: 7          error: 0.6490725194878566
# 	 iteration: 8          error: 0.026407195350058008
# 	 iteration: 9          error: 0.00019275696695528945
# 	 iteration: 10         error: 1.2553058008651092e-08
# Solving for V = 0.0
# 	 iteration: 1          error: 4219.858925720523
# 	 iteration: 2          error: 0.41854697231176313
# 	 iteration: 3          error: 0.1163357677224115
# 	 iteration: 4          error: 0.007315459414078797
# 	 iteration: 5          error: 2.6888835170433188e-05
# 	 iteration: 6          error: 3.615193439611891e-10
# Solving for V = 0.014351523775676034
# 	 iteration: 1          error: 4.746546657419992
# ...

# %%
print(eff)
print(gradients)
# Out:
# 1.1413331450560582e-05
# {'A': DeviceArray([ 1.26798069e-03,  9.80312023e-04,  8.03393121e-04,
#               6.36583942e-04,  4.82881791e-04,  3.45528385e-04,
#               2.28060676e-04,  1.33762502e-04,  6.44943891e-05,
#               1.93440286e-05, -8.61291672e-06, -2.66421388e-05,
#              -3.85450497e-05, -4.64818992e-05, -5.17530935e-05,
#              -5.51721416e-05, -5.72599094e-05, -5.83541364e-05,
#              -5.86762193e-05, -5.83750862e-05, -5.75576068e-05,
#              -5.63098492e-05, -5.47110290e-05, -5.28410858e-05,
#              -5.07828124e-05, -4.86198385e-05, -4.64321072e-05,
#              -4.42905090e-05, -4.22520203e-05, -4.03562186e-05,
#              -3.86236142e-05, -3.70560080e-05, -3.56389719e-05,
#              -3.43463485e-05, -3.31461873e-05, -3.20067589e-05,
#              -3.09319333e-05, -2.98780496e-05, -2.88259644e-05,
#              -2.77707286e-05, -2.67147263e-05, -2.56630652e-05,
# ...
