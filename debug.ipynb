# %%
import jaxpv
from jax import numpy as np, ops
import matplotlib.pyplot as plt
from jax.scipy.sparse.linalg import gmres
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
spm = np.load("spgradF_1610236896_8805609.npy")
spi = ops.index_update(np.zeros_like(spm), ops.index[:, 6], 1)
v = np.load("F_1610236896_8805609.npy")
m = jaxpv.linalg.sparse2dense(spm)

# %%
np.allclose(jaxpv.linalg.linsol(spi, v), v)
np.allclose(m @ np.linalg.solve(m, v), v)
# Out:
# DeviceArray(True, dtype=bool)

# %%
jaxpv.linalg.linsol(spm, v)
# Out:
# Invalid value encountered in the output of a jit function. Calling the de-optimized version.
# ---------------------------------------------------------------------------
# FilteredStackTrace                        Traceback (most recent call last)
# <ipython-input-37-1084354c0e7d> in <module>
# ----> 1 jaxpv.linalg.linsol(spm, v)
#
# ~/Dropbox (MIT)/MIT/RomanoLab/jaxpv_project/jaxpv/jaxpv/linalg.py in linsol(spmat, vec)
#     132
# --> 133     sol, _ = gmres(mvp, vec, M=precond, tol=1e-12, atol=0., maxiter=10)
#     134
#
# ~/opt/anaconda3/envs/jaxpv/lib/python3.7/site-packages/jax/_src/scipy/sparse/linalg.py in gmres(A, b, x0, tol, atol, restart, maxiter, M, solve_method)
#     621     return _gmres_solve(A, b, x0, atol, ptol, restart, maxiter, M, gmres_func)
# --> 622   x = lax.custom_linear_solve(A, b, solve=_solve, transpose_solve=_solve)
#     623
#
# ...
